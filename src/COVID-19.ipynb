# %%
using CSV
using DataFrames
using DataFramesMeta
using StatsPlots
using DifferentialEquations
using Dates

# %% [markdown]
# This is more a data science post than machine learning. It was born after reading a [report](https://www.imperial.ac.uk/media/imperial-college/medicine/sph/ide/gida-fellowships/Imperial-College-COVID19-NPI-modelling-16-03-2020.pdf) from Imperial College London and finding a forecasting model by [NeherLab](https://neherlab.org/covid19/). The numbers produced by those models can only be described as terrifying.

# %% [markdown]
# How do those models work? How are they calibrated?

# %% [markdown]
# __BUT__

# %% [markdown]
# Whatever concerns one can have about their precision, those models are all absolutely clear that social-distancing, quarantining have a massive impact on death rates. Being careful saves lives. If anybody feels like ignoring those precautions out of excess testosterone, they are at risk of killing others.

# %% [markdown]
# This post started from one of the pages of the NeherLab site describing their methodology. The work that team is achieving deserves more credit than I can give them.

# %% [markdown]
# The NeherLab website, including the model, is entirely written in Javascript. This is difficul to understand and audit.

# %% [markdown]
# # Basic assumptions

# %% [markdown]
# ### Overview
#
# The model works as follows:
#
#  - susceptible individuals are exposed/infected through contact with infectious individuals. Each infectious individual causes on average $R_0$ secondary infections while they are infectious.
#
# Transmissibility of the virus could have seasonal variation which is parameterized with the parameter "seasonal forcing" (amplitude) and "peak month" (month of most efficient transmission).
#
# - exposed individuals progress to a symptomatic/infectious state after an average latency
#
# - infectious individuals recover or progress to severe disease. The ratio of recovery to severe progression depends on age
#
# - severely sick individuals either recover or deteriorate and turn critical. Again, this depends on the age
#
# - critically ill individuals either return to regular hospital or die. Again, this depends on the age
#
# The individual parameters of the model can be changed to allow exploration of different scenarios.
#
# <figure className="figure w-100 text-center">
#   <img src={model} className="w-75 figure-img" alt="illustration of the model" />
#   <figcaption className="figure-caption text-center">
#     Figure 1. A schematic illustration of the underlying model. S corresponds to the 'susceptible' population,
#     E is 'exposed', I is 'infectious', R 'recovered', H 'severe' (hospitalized), C 'critical' (ICU), and D are
#     fatalities.
#   </figcaption>
# </figure>

# %% [markdown]
# ### Age cohorts
#
# COVID-19 is much more severe in the elderly and proportion of elderly in a community is therefore an important determinant of the overall burden on the health care system and the death toll. We collected age distributions for many countries from data provided by the UN and make those available as input parameters. Furthermore, we use data provided by the epidemiology group by the [Chinese CDC](http://weekly.chinacdc.cn/en/article/id/e53946e2-c6c4-41e9-9a9b-fea8db1a8f51) to estimate the fraction of severe and fatal cases by age group.

# %% [markdown]
# ### Severity
#
# The basic model deals with 3 levels of severity: slow, moderate and fast transmissions.

# %%
# severityLevel = :slow
severityLevel = :moderate
# severityLevel = :fast
# Out:
# :moderate

# %% [markdown]
# ## Seasonality
#
# Many respiratory viruses such as influenza, common cold viruses (including other coronaviruses) have a pronounced seasonal variation in incidence which is in part driven by climate variation through the year. We model this seasonal variation using a sinusoidal function with an annual period. This is a simplistic way to capture seasonality. Furthermore, we don't know yet how seasonality will affect COVID-19 transmission.
#
# <figure className="figure w-100 text-center">
#   <img
#     src={seasonalIllustration}
#     className="w-75 figure-img img-fluid"
#     alt="illustration of seasonal variation in transmission rate"
#   />
#   <figcaption className="figure-caption text-center">
#     Figure 2. Seasonal variation in transmission rate is modeled by a cosine. The model allows to specify the
#     average R0, the amplitude of the cosine (seasonal forcing), and the month of peak transmission.
#   </figcaption>
# </figure>

# %%
# Northern or southern hemisphere
latitude = :north
# latitude = :tropical
# latitude = :south
# Out:
# :north

# %%
# The time unit is days (as floating point)
# Day 0 is taken at 1 March 2020
BASE_DATE = Date(2020, 3, 1)
BASE_DAYS = 0

function date2days(d) 
    return convert(Float64, datetime2rata(d) - datetime2rata(BASE_DATE))
end

function days2date(d) 
    return BASE_DATE + Day(d)
end
# Out:
# days2date (generic function with 1 method)

# %%
# Default values for R_0
baseR₀ = Dict( (:north,    :slow)     => 2.2, 
               (:north,    :moderate) => 2.7, 
               (:north,    :fast)     => 3.2, 
               (:tropical, :slow)     => 2.0, 
               (:tropical, :moderate) => 2.5, 
               (:tropical, :fast)     => 3.0,
               (:south,    :slow)     => 2.2, 
               (:south,    :moderate) => 2.7, 
               (:south,    :fast)     => 3.2)
# Out:
# Dict{Tuple{Symbol,Symbol},Float64} with 9 entries:
#   (:tropical, :slow)     => 2.0
#   (:tropical, :moderate) => 2.5
#   (:north, :slow)        => 2.2
#   (:south, :slow)        => 2.2
#   (:north, :moderate)    => 2.7
#   (:south, :fast)        => 3.2
#   (:north, :fast)        => 3.2
#   (:tropical, :fast)     => 3.0
#   (:south, :moderate)    => 2.7

# %%
# Peak date
peakDate = Dict( :north     => date2days(Date(2020, 1, 1)), 
                 :tropical  => date2days(Date(2020, 1, 1)),    # although no impact
                 :south     => date2days(Date(2020, 7, 1)))
# Out:
# Dict{Symbol,Float64} with 3 entries:
#   :tropical => -60.0
#   :south    => 122.0
#   :north    => -60.0

# %%
# Seasonal forcing parameter \epsilon
ϵ = Dict( (:north,    :slow)     => 0.2, 
          (:north,    :moderate) => 0.2, 
          (:north,    :fast)     => 0.1, 
          (:tropical, :slow)     => 0.0, 
          (:tropical, :moderate) => 0.0, 
          (:tropical, :fast)     => 0.0,
          (:south,    :slow)     => 0.2, 
          (:south,    :moderate) => 0.2, 
          (:south,    :fast)     => 0.1)
# Out:
# Dict{Tuple{Symbol,Symbol},Float64} with 9 entries:
#   (:tropical, :slow)     => 0.0
#   (:tropical, :moderate) => 0.0
#   (:north, :slow)        => 0.2
#   (:south, :slow)        => 0.2
#   (:north, :moderate)    => 0.2
#   (:south, :fast)        => 0.1
#   (:north, :fast)        => 0.1
#   (:tropical, :fast)     => 0.0
#   (:south, :moderate)    => 0.2

# %%
# Gives R_0 at a given date
function R₀(d; r_0 = missing, latitude = :north, severity = :moderate)
    if ismissing(r_0)
        r₀ = baseR₀[(latitude, severity)]
    else
        r₀ = r_0
    end
    eps = ϵ[(latitude, severity)]
    peak = peakDate[latitude]
    
    return r₀ * (1 + eps * cos(2.0 * π * (d - peak) / 365.25))
end
# Out:
# R₀ (generic function with 1 method)

# %% [markdown]
# ## Transmission reduction
#
# The tool allows one to explore temporal variation in the reduction of transmission by infection
# control measures. This is implemented as a curve through time that can be dragged by the mouse to
# modify the assumed transmission. The curve is read out and used to change the transmission relative
# to the base line parameters for $R_0$ and seasonality. Several studies attempt to estimate the
# effect of different aspects of social distancing and infection control on the rate of transmission.
# A report by [Wang et al](https://www.medrxiv.org/content/10.1101/2020.03.03.20030593v1) estimates a
# step-wise reduction of $R_0$ from above three to around 1 and then to around 0.3 due to successive
# measures implemented in Wuhan. [This study](https://www.pnas.org/content/116/27/13174) investigates
# the effect of school closures on influenza transmission.
#
# This curve is presented as a list of tuples: (days from start date, ratio). The month starts from the start date. Between dates, the ration is interpolated linearly. After the last date, the ration remains constant.

# %%
startDate = date2days(Date(2020, 3, 1))
mitigationRatio = [(0, 1.00), (30, 0.80), , (60, 0.50)]

function getCurrentRatio(d; start = BASE_DAYS, schedule = mitigationRatio)
    l = length(schedule)
    
    # If l = 1, ratio will be the only one
    if l == 1 
        return schedule[1][2]
    else
        for i in 2:l
            d1 = schedule[i-1][1]
            d2 = schedule[i  ][1]
            
            if d < d2 
                deltaR = schedule[i][2] - schedule[i-1][2]
                return schedule[i-1][2] + deltaR * (d - d1) / (d2 - d1)
            end
        end
    
        # Last possible choice
        return schedule[l][2]
    end
end
# Out:
# syntax: unexpected ","

# %% [markdown]
# ## Details of the model

# %% [markdown]
# Age strongly influences an individual's response to the virus. The general population is sub-divided in to age classes, indexed by $a$, to allow for variable transition rates dependent upon age.

# %%
# The population will be modeled as a single vector. 
# The vector will be a stack of several vectors, each of them represents a compartment.
# Each compartment vector has a size $nAgeGroup$ representing each age group.
# The compartments are: S, E, I, H, C, R, D, K, L

# We also track the hospital bed usage BED and ICU

# Compartments to population
#function Comp2Pop(S, E, I, H, C, R, D, K, L, BED, ICU)
#    return cat(S, E, I, H, C, R, D, K, L, BED, ICU)
#end

# Population to compartments
function Pop2Comp(P)
    
    # To make copy/paste less prone to error 
    g = 0
    
    S = P[ g*nAgeGroup + 1: (g+1)*nAgeGroup]; g += 1
    E = P[ g*nAgeGroup + 1: (g+1)*nAgeGroup]; g += 1
    I = P[ g*nAgeGroup + 1: (g+1)*nAgeGroup]; g += 1
    J = P[ g*nAgeGroup + 1: (g+1)*nAgeGroup]; g += 1
    H = P[ g*nAgeGroup + 1: (g+1)*nAgeGroup]; g += 1
    C = P[ g*nAgeGroup + 1: (g+1)*nAgeGroup]; g += 1
    R = P[ g*nAgeGroup + 1: (g+1)*nAgeGroup]; g += 1
    D = P[ g*nAgeGroup + 1: (g+1)*nAgeGroup]; g += 1
    K = P[ g*nAgeGroup + 1: (g+1)*nAgeGroup]; g += 1
    L = P[ g*nAgeGroup + 1: (g+1)*nAgeGroup]; g += 1
    
    BED = P[ g*nAgeGroup + 1: g*nAgeGroup + 1]
    ICU = P[ g*nAgeGroup + 2: g*nAgeGroup + 2]
    
    return S, E, I, J, H, C, R, D, K, L, BED, ICU
end
# Out:
# Pop2Comp (generic function with 1 method)

# %% [markdown]
# ### Population compartments
#
# Qualitatively, the epidemy model dynamics tracks several sub-groups (compartments):

# %% [markdown]
# <img src="States.svg">

# %% [markdown]
# * Susceptible individuals ($S$) are healthy and susceptible to being exposed to the virus by contact with an infected individual.

# %% [markdown]
# * Exposed individuals ($E$) are infected but asymptomatic. They progress towards a symptomatic state on average time $t_l$. Reports are that asymptomatic individuals are contagious. We will assume that they are proportionally less contagious than symptomatic individuals as a percentage $\gamma_E$ of $R_0$. For the purposes of modelling we will assume (without supporting evidence, but will be the object of parameter estimation):

# %%
γₑ = 0.50
# Out:
# 0.5

# %% [markdown]
# * Infected individuals ($I$) infect an average of $R_0$ secondary infections. On a time-scale of $t_i$, infected individuals either recover or progress towards severe infection.

# %% [markdown]
# From here on, the compartments differ from the NeherLab model is that we split compartments depending on the severity of the symptoms (Severe or Critical) and the location of the individual (out of the hospital infrastructure, isolated in hospital, or isolated in intensive care units). The transitions reflect the following assumptions:
#
# * Transition between locations is purely a function of bed availability: as soon as beds are available, they are filled by all age groups in their respective proportions.
#
# * Transition from severe to critical is assumed to be independent from the location of the patient. For severe patients, the relevance of the location is whether they are isolated or not, that is the possibility to infect susceptible individual. The same way an asymptomatic individual's attracts a ratio $\gamma_e$, the other compartments will. The transition from $J$ and $H$ to recovery or criticality has a time-scale of $t_h$.

# %%
# R_0 multipliers depending on severity. Subscript matches the compartment's name.
# Infected / symptomatic individuals
γᵢ=1.0

# Severe symptoms
γⱼ=1.5

# Critical symptoms
γₖ = 2.0
# Out:
# 2.0

# %% [markdown]
# * Once critical, the location of a patient influences their chances of recovery. Although we will assume that the time to recovery is identical in all cases, we will assume that the risks will double and triple if a patient is in simple isolation (receiving care but without ICU equipmment) or out of hospital.

# %%
# Fatality mulitplier.

# In ICU
δᵤ = 1.0

# In hospital
δₗ = 2.0

# Out of hospital
δₖ = 3.0
# Out:
# 3.0

# %% [markdown]
# * The time-scale to recovery ($R$) or death ($D$) is $t_u$.

# %% [markdown]
# * Recovering and recovered individuals [$R$] can not be infected again. We will assume that recovering individual are not contagious (no medical experience for this assumption for recovering individual).

# %% [markdown]
# ### Model parameters

# %% [markdown]
#  * Many estimates of $R_0$ are in the [range of 2-3](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7001239/) with some estimates pointing to considerably [higher values](https://www.medrxiv.org/content/10.1101/2020.02.10.20021675v1).
#  * The serial interval, that is the time between subsequent infections in a transmission chain, was [estimated to be 7-8 days](https://www.nejm.org/doi/full/10.1056/NEJMoa2001316).
#  * The China CDC compiled [extensive data on severity and fatality of more than 40 thousand confirmed cases](http://weekly.chinacdc.cn/en/article/id/e53946e2-c6c4-41e9-9a9b-fea8db1a8f51).
#  In addition, we assume that a substantial fraction of infections, especially in the young, go unreported. This is encoded in the columns "Confirmed [% of total]".
#  * Seasonal variation in transmission is common for many respiratory viruses but the strength of seasonal forcing for COVID19 are uncertain. For more information, see a [study by us](https://smw.ch/article/doi/smw.2020.20224) and by [Kissler et al](https://www.medrxiv.org/content/10.1101/2020.03.04.20031112v1).
# The parameters of this model fall into three categories: transition time scales, age-specfic parameters and a time-dependent infection rate.

# %% [markdown]
# #### Transition time scales
#
# The time scales of transition from a compartment to the next: $t_l$, $t_i$, $t_h$, $t_c$.
#
# * $t_l$: latency time from infection to infectiousness
# * $t_i$: the time an individual is infectious after which he/she either recovers or falls severely ill
# * $t_h$: the time a sick person recovers or deteriorates into a critical state
# * $t_u$: the time a person remains critical before dying or stabilizing (Neherlab uses $t_c$ instead of $t_u$)

# %%
# Time to infectiousness (written t\_l)
tₗ = Dict(  :slow     => 5.0, 
            :moderate => 5.0, 
            :fast     => 4.0)

# Time to infectiousness (written t\_i)
tᵢ = Dict(  :slow     => 3.0, 
            :moderate => 3.0, 
            :fast     => 3.0)

# Time in hospital bed (not ICU)
tₕ = 4.0

# Time in ICU 
tᵤ = 14.0
# Out:
# 14.0

# %% [markdown]
# #### Age-specfic parameters
#
# The age-specific parameters $z_a$, $m_a$, $c_a$ and $f_a$ that determine relative rates of different outcomes.
#
# * $z_a$: a set of numbers reflecting to which extent an age group is susceptible to initial contagion. Note that NeherLab denotes this vector by $I_a$ which is confusing with the compartmment evolution $I_a(t)$ notation. (This sort of defeats the purpose of $R_0$.)
# * $m_a$: fraction of infectious becoming severe (__Hospitalisation Rate__) or recovers immediately (__Recovery Rate__)
# * $c_a$: fraction of severe cases that turn critical (__Critical Rate__) or can leave hospital (__Discharge Rate__)
# * $f_a$: fraction of critical cases that are fatal (__Death Rate__) or recover (__Stabilisation Rate__)

# %%
AgeGroup = ["0-9", "10-19", "20-29", "30-39", "40-49", "50-59", "60-69", "70-79", "80+"]
zₐ =       [0.05,   0.05,   0.10,    0.15,    0.20,    0.25,    0.30,    0.40,    0.50]
#zₐ =       [1.00,   1.00,   1.00,    1.00,    1.00,    1.00,    1.00,    1.00,    1.00]   
mₐ =       [0.01,   0.03,   0.03,    0.03,    0.06,    0.10,    0.25,    0.35,    0.50]
cₐ =       [0.05,   0.10,   0.10,    0.15,    0.20,    0.25,    0.35,    0.45,    0.55]
fₐ =       [0.30,   0.30,   0.30,    0.30,    0.30,    0.40,    0.40,    0.50,    0.50]

nAgeGroup = length(AgeGroup)
# Out:
# 9

# %% [markdown]
# #### Infrastruture
#
# The number of beds available is assumed as a fixed resource in time. The number of hospital (resp. ICU) beds in use will be denoted $\mathscr{H}(t)$ (resp. $\mathscr{U}(t)$)  up to a maximum of $\mathscr{H}_{max}$ (resp. $\mathscr{U}_{max}$).
#
# Although the initial infections took place via dommestic and international travellers (apart from the initial infections in Wuhan obviously), we will assume no net flow of population in and out of a country of interest.

# %% [markdown]
# ### Infection

# %% [markdown]
# #### Susceptible:
#
# The _base_ rate of contagion is denoted as $R_0$. The actual rate varies with time (to reflect seasons and impact of temperature on virus resilience) and the effectiveness of the mitigation measures such as social distancing. Separately, each age group will have a different sensitivity to infection.
#
# The infection rate $\beta_a(t)$ is age- and time-dependent. It is given by:
#
# $$\beta_a(t) = z_a M(t) R_0 \left( 1+\varepsilon \cos \left( 2\pi \frac{t-t_{max}}{t_i} \right) \right) $$
#
# where:
#
# * $z_a$ is the degree to which particular age groups are sensitive to initial infection. It reflects bioligical sensitivity and to which degree it is isolated from the rest of the population (denoted $I_a$ in NeherLab).
# * $M(t)$ is a time-dependent ratio reflecting the effectiveness of mitigation measures.
# * $\varepsilon$ is the amplitude of seasonal variation in transmissibility.
# * $t_{max}$ is the time of the year of peak transmission.

# %% [markdown]
# Susceptible individuals are exposed to a number of contagious individuals:
#
# * asymptomatic infected:  $$\gamma_e \beta_a(t) E_a(t)$$
# * symptomatic infected: $$\gamma_i \beta_a(t) I_a(t)$$
# * severe not in hospital: $$\gamma_j \beta_a(t) J_a(t)$$
# * critical not in hospital: $$\gamma_k \beta_a(t) K_a(t)$$
#
# The sum of those will be a flow from susceptible ($S$) to ($E$) exposed individuals.
#
# $$
# \begin{aligned}
# S2E_a(t) & = \gamma_e \beta_a(t) E_a(t) + \gamma_i \beta_a(t) I_a(t) + \gamma_j \beta_a(t) K_a(t) + \gamma_k \beta_a(t) L_a(t) \\
# S2E_a(t) & = \beta_a(t) \left( \gamma_e  E_a(t) + \gamma_i I_a(t) + \gamma_j J_a(t) + \gamma_k K_a(t) \right) \\
# E2S_a(t) & = -S2E_a(t) \\
# \end{aligned}
# $$

# %% [markdown]
# and therefore:
#
# $$
# \frac{dS_{a}(t)}{dt} = - S2E_a(t) = E2S_a(t)
# $$

# %% [markdown]
# ### After infection
#
# Quantitatively, the model expresses how many individuals transfer from one situation/compartment to another. Flows from compartment X to Y are written as $X2Y$ (obviously $X2Y = - Y2X$).
#
# Note that the compartments are split into age groups.

# %% [markdown]
# <img src="Transitions.svg">

# %% [markdown]
# #### Epidemiology

# %% [markdown]
# Instead of expressing the sum of the flows at each node, it is easier to express the arrows, and summing them afterwards. For example, arrow from $J$ to $K$ will be:
#
# $$JK_a(t) = \frac{c_a}{t_h} J_a(t)$$
#
# with a positive flow following the direction of the arrow.
#
# In Julia, this will become:
#
# ```
#         JK = cₐ .* J / tₕ
# ```
# where `J` is a vector representing an age group, `.*` is the element-wise multiplication.
#
# After defining the arrows $IJ$, $JK$ and $JH$, the change in $J$ will simply be:
#
# ```
#         dJ = IJ - JK - JH
# ```

# %% [markdown]
# #### Bed transfers

# %% [markdown]
# Individuals are transferred into hospital beds then into ICU beds in the order indicated by the red numbers.
#
# Critical patients already in hospital go into ICU as spots become available. The freed bed are first made available to critical patients out of hospital ($K$). Then, any free beds will receive patients in severe condition.

# %% [markdown]
# #### Safeguards:
#
# Note the need to ensure a few common sense rules:
#
# * No compartment can have a negative number of people.
#
# * The total population figure should remain unchanged. This is done by adjusting the number of susceptible individuals.
#
# * Careful accounting of the use of fixed number of hospital beds.
#
# * The number of infected people should always be above the number of reported cases.

# %%
# Helper function to never change the number of individuals in a compartment in a way that would 
# make it below 0.1 (to avoid rounding errors around 0)
function ensurePositive(d,s)
    return max.(d .+ s, 0.1) .- s
end

    
    
# The dynamics of the epidemy is a function that mutates its argument with a precise signature
# Don't pay too much attetion to the print debugs/

function epiDynamics!(dP, P, params, t)
    
    S, E, I, J, H, C, R, D, K, L, BED, ICU = Pop2Comp(P)
    
    BED = BED[1]
    ICU = ICU[1]
    
    r₀, tₗ, tᵢ, tₕ, tᵤ, γₑ, γᵢ, γⱼ, γₖ, δₖ, δₗ, δᵤ, startDays = params 
    
    
    ####################################
    # Arrows reflecting epidemiology - Check signs (just in case)
    EI = ones(nAgeGroup) .* E / tₗ;  EI = max.(EI, 0.0); IE = -EI; 
    IJ = mₐ              .* I / tᵢ;  IJ = max.(IJ, 0.0); JI = -IJ
    JK = cₐ              .* J / tₕ;  JK = max.(JK, 0.0); KJ = -JK
    HL = cₐ              .* H / tₕ;  HL = max.(HL, 0.0); LH = -HL
    
    # Recovery arrows
    IR = (1 .- mₐ)       .* I / tᵢ;  IR = max.(IR, 0.0); RI = -IR
    JR = (1 .- cₐ)       .* J / tₕ;  JR = max.(JR, 0.0); RJ = -JR
    HR = (1 .- cₐ)       .* H / tₕ;  HR = max.(HR, 0.0); RH = -HR
    KR = (1 .- δₖ .* fₐ) .* K / tᵤ;  KR = max.(KR, 0.0); RK = -KR
    LR = (1 .- δₗ .* fₐ) .* L / tᵤ;  LR = max.(LR, 0.0); RL = -LR
    CR = (1 .- δᵤ .* fₐ) .* C / tᵤ;  CR = max.(CR, 0.0); RC = -CR
    
    # Deaths
    KD = δₖ .* fₐ        .* K / tᵤ;  KD = max.(KD, 0.0); DK = -KD
    LD = δₗ .* fₐ        .* L / tᵤ;  LD = max.(LD, 0.0); DL = -LD
    CD = δᵤ .* fₐ        .* C / tᵤ;  CD = max.(CD, 0.0); DC = -CD
    
    
    ####################################
    # Bed transfers
    
    ####### Step 1:
    # Decrease in bed usage is (recall that CD and CR are vectors over the age groups) 
    dICU = - (sum(CD) + sum(CR));                 dICU = ensurePositive(dICU, ICU)
    
    # ICU beds available
    ICU_free = ICU_max - (ICU + dICU)
    
    # Move as many patients as possible from $L$ to $C$ in proportion of each group
    ICU_transfer = min(sum(L), ICU_free)
    LC = ICU_transfer / sum(L) .* L;    CL = -LC
    
    # Overall change in ICU bed becomes
    dICU = dICU + ICU_transfer;                   dICU = ensurePositive(dICU, ICU)
    
    # And some normal beds are freed
    dBED = -ICU_transfer;                         dBED = ensurePositive(dBED, BED)
    print(" dBed step 1 "); println(floor.(sum(dBED)))

    ####### Step 2:
    # Beds available
    BED_free = BED_max - (BED + dBED)
    
    # Move as many patients as possible from $K$ to $L$ in proportion of each group
    BED_transfer = min(sum(K), BED_free)
    KL = BED_transfer / sum(K) .* K;   LK = -KL
    
    # Overall change in normal bed becomes
    dBED = dBED + BED_transfer;                   dBED = ensurePositive(dBED, BED)
    print(" dBed step 2 "); println(floor.(sum(dBED)))
    

    ####### Step 3:
    # Beds available
    BED_free = BED_max - (BED + dBED)
    
    # Move as many patients as possible from $J$ to $H$ in proportion of each group
    BED_transfer = min(sum(J), BED_free)
    JH = BED_transfer / sum(J) .* J;   HJ = -JH 
    
    # Overall change in ICU bed becomes
    dBED = dBED + BED_transfer;                   dBED = ensurePositive(dBED, BED)
    print(" dBed step 3 "); println(floor.(sum(dBED)))
    

    ####################################
    # Sum of all flows + Check never negative compartment
    
    # Susceptible    
    # Calculation of β
    β = getCurrentRatio(t; start = BASE_DAYS, schedule = mitigationRatio) .* zₐ .* 
        R₀(t; r_0 = r₀, latitude = Latitude, severity = SeverityLevel)
    
    #print("r₀"); println(r₀); println("R₀"); 
    #println(R₀(t; r_0 = r₀, latitude = Latitude, severity = SeverityLevel)); print()
    
    dS = -β .* (γₑ.*E + γᵢ.*I + γⱼ.*J + γₖ.*K);   dS = min.(-0.01, dS); dS = ensurePositive(dS, S)
    
    #print("dS"); println(floor.(dS)); println(); 
    
    # Exposed
    dE = -dS + IE;                                dE = ensurePositive(dE, E)
    
    # Infected. 
    dI = EI + JI + RI;                            dI = ensurePositive(dI, I)
    
    # Infected no hospital
    dJ = IJ + HJ + KJ + RJ;                       dJ = ensurePositive(dJ, J)
    
    #print("I "); println(floor.(IJ)); print("H "); println(floor.(HJ))
    #print("K "); println(floor.(KJ)); print("R "); println(floor.(RJ))
    
    # Infected in hospital
    dH = JH + LH + RH ;                           dH = ensurePositive(dH, H)
    
    # Critical no hospital
    dK = JK + LK + DK + RK;                       dK = ensurePositive(dK, K)
    
    # Critical in hospital
    dL = KL + HL + CL + DL + RL;                  dL = ensurePositive(dL, L)
    
    # Critical in ICU
    dC = LC + DC + RC;                            dC = ensurePositive(dC, C)
    
    # Recovery (can only increase)
    dR = IR + JR + HR + KR + LR + CR;             dR = max.(dR, 0.01)
    
    # Dead (can only increase)
    dD = KD + LD + CD;                            dD = max.(dD, 0.01)
    
    # Vector change of population and update in place
    result = vcat(dS, dE, dI, dJ, dH, dC, dR, dD, dK, dL, [dBED], [dICU])
    #print(" dS "); print(floor.(sum(dS))); print(" dE "); print(floor.(sum(dE))); 
    #print(" dI "); print(floor.(sum(dI))); print(" dJ "); println(floor.(sum(dJ))); 
    #print(" dH "); print(floor.(sum(dH))); print(" dC "); print(floor.(sum(dC))); 
    #print(" dR "); print(floor.(sum(dR))); print(" dD "); print(floor.(sum(dD))); 
    #print(" dK "); print(floor.(sum(dK))); print(" dL "); println(floor.(sum(dL))); println(); 
    for i = 1:length(result)
        dP[i] = result[i]
    end

end
# Out:
# epiDynamics! (generic function with 1 method)

# %% [markdown]
# # Load data

# %% [markdown]
# The data comes from Neherlab's data repository on [Github](https://github.com/neherlab/covid19_scenarios_data).

# %%
# Adjust as necessary. The data lives in a data/ folder below this.
cd("$(homedir())/Development/julia/projects/NeherlabJulia/")

# %% [markdown]
# We will use Italy as an example

# %%
country = "Italy"
# Out:
# "Italy"

# %%
populationData = DataFrame(CSV.read("data/populationData.tsv"))
populationData = @where(populationData, occursin.(country, :name)) 
first(populationData, 6)
# Out:
# 1×7 DataFrame. Omitted printing of 2 columns
# │ Row │ name   │ populationServed │ ageDistribution │ hospitalBeds │ ICUBeds │
# │     │ String │ Int64            │ String          │ Int64        │ Int64   │
# ├─────┼────────┼──────────────────┼─────────────────┼──────────────┼─────────┤
# │ 1   │ Italy  │ 60462000         │ Italy           │ 165384       │ 7550    │

# %% [markdown]
# This file contains a record of cases day by day.

# %%
cases = DataFrame(CSV.read("data/World.tsv", header = 4))
cases = @where(cases, occursin.(country, :location)) 
sort!(cases, :time)
last(cases, 6)
# Out:
# 6×7 DataFrame. Omitted printing of 1 columns
# │ Row │ location │ time       │ cases │ deaths │ hospitalized │ ICU     │
# │     │ String   │ Date       │ Int64 │ Int64  │ Missing      │ Missing │
# ├─────┼──────────┼────────────┼───────┼────────┼──────────────┼─────────┤
# │ 1   │ Italy    │ 2020-03-17 │ 27980 │ 2158   │ missing      │ missing │
# │ 2   │ Italy    │ 2020-03-18 │ 31506 │ 2505   │ missing      │ missing │
# │ 3   │ Italy    │ 2020-03-19 │ 35713 │ 2978   │ missing      │ missing │
# │ 4   │ Italy    │ 2020-03-20 │ 41035 │ 3407   │ missing      │ missing │
# │ 5   │ Italy    │ 2020-03-21 │ 47021 │ 4032   │ missing      │ missing │
# │ 6   │ Italy    │ 2020-03-22 │ 53578 │ 4827   │ missing      │ missing │

# %% [markdown]
# This file contains ICU beds figures.

# %%
ICU_capacity = select(CSV.read("data/ICU_capacity.tsv"; delim = "\t"), :country, :CriticalCare)
ICU_capacity = @where(ICU_capacity, occursin.(country, :country))[!, :CriticalCare][1]
ICU_capacity = convert(Float64, ICU_capacity)
# Out:
# thread = 1 warning: only found 6 / 9 columns on data row: 32. Filling remaining columns with `missing`
# 7550.0

# %% [markdown]
# Country codes are necessary to load the another file.

# %%
country_codes = select(CSV.read("data/country_codes.csv"), :name, Symbol("alpha-3"))
country_codes = @where(country_codes, occursin.(country, :name))
countryShort = country_codes[:, Symbol("alpha-3")][1]
# Out:
# thread = 1 warning: only found 10 / 11 columns on data row: 121. Filling remaining columns with `missing`
# "ITA"

# %% [markdown]
# This file contains hospital beds figures.

# %%
hospital_capacity = select(CSV.read("data/hospital_capacity.csv", types = Dict(:COUNTRY => String), limit = 1267), :COUNTRY, :YEAR, :VALUE)
hospital_capacity = @where(hospital_capacity, Not(ismissing.(:COUNTRY)))
hospital_capacity = last(@where(hospital_capacity, occursin.(countryShort, :COUNTRY)), 1)[!, :VALUE][1]
hospital_capacity = convert(Float64, hospital_capacity)
# Out:
# 165384.0

# %% [markdown]
# This file contains a distribution of the population in age groups.

# %%
age_distribution = CSV.read("data/country_age_distribution.csv")
age_distribution = @where(age_distribution, occursin.(country, :_key))[!, 2:10]
# Convert to simple matrix
age_distribution = Matrix(age_distribution)
show(age_distribution)
# Out:
# [4994996 5733447 6103437 6998434 9022004 9567192 7484860 6028907 4528548]

# %% [markdown]
# # Initialise parameters

# %% [markdown]
# ## Fixed constants

# %%
SeverityLevel = :moderate
Latitude = :north

StartDate = Date(2020, 3, 1)
StartDays = date2days(StartDate)

EndDate = Date(2020, 12, 1)
EndDays = date2days(EndDate)

tSpan = (StartDays, EndDays)
# Out:
# (0.0, 275.0)

# %% [markdown]
# ## Infrastructure

# %%
BED_max = hospital_capacity
# Out:
# 165384.0

# %%
ICU_max = ICU_capacity
# Out:
# 7550.0

# %% [markdown]
# ## Parameter vector

# %%
# r₀, tₗ, tᵢ, tₕ, tᵤ, γᵢ, γⱼ, γₖ, δₖ, δₗ, δᵤ, startDate = params 

parameters = [  baseR₀[Latitude, SeverityLevel], 
                tₗ[SeverityLevel], tᵢ[SeverityLevel], tₕ, tᵤ, 
                γₑ, γᵢ, γⱼ, γₖ, 
                δₖ, δₗ, δᵤ, 
                StartDays];

# %% [markdown]
# ## Population

# %%
Age_Pyramid = transpose(age_distribution)
Age_Pyramid_frac = Age_Pyramid / sum(Age_Pyramid);

# %% [markdown]
# We do not know the number of actual number of infections cases at the start of the model. We only know confirmed cases (almost certainly far below the number of actual infections).
#
# We assume that actual infections are 3 time more numerous.

# %%
DeathsAtStart = @where(cases, :time .== StartDate)[!, :deaths][1]
ConfirmedAtStart = @where(cases, :time .== StartDate)[!, :cases][1]
EstimatedAtStart = 3.0 * ConfirmedAtStart
# Out:
# 3384.0

# %% [markdown]
# ## Parameters vector

# %%
# Note that values are inintialised at 1 to avoid division by zero

S0 = Age_Pyramid
E0 = ones(nAgeGroup)
I0 = EstimatedAtStart * Age_Pyramid_frac
J0 = ones(nAgeGroup)
H0 = ones(nAgeGroup)
C0 = ones(nAgeGroup)
R0 = ones(nAgeGroup)
D0 = DeathsAtStart * Age_Pyramid_frac
K0 = ones(nAgeGroup)
L0 = ones(nAgeGroup)

# Everybody confirmed is in hospital
BED = [ConfirmedAtStart]
ICU = [1.0]

P0 = vcat(S0, E0, I0, J0, H0, C0, R0, D0, K0, L0, BED, ICU)
dP = 0 * P0;

# %% [markdown]
# # Differential equation solver

# %%
model = ODEProblem(epiDynamics!, P0, tSpan, parameters);

# %%
# Note: progress steps might be too quick to see!
sol = solve(model, Tsit5(); progress = true, progress_steps = 5)
# Out:
# ODE:   0%|                                         |  ETA: 0:02:13
#  dBed step 1 -9.0
#  dBed step 2 0.0
#  dBed step 3 9.0
#  dBed step 1 -9.0
#  dBed step 2 0.0
#  dBed step 3 9.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 9.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 9.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 9.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 10.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 10.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 10.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 10.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 12.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 13.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 19.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 19.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 19.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 19.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 21.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 23.0
#  dBed step 1 -9.0
#  dBed step 2 -1.0
#  dBed step 3 28.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 29.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 29.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 29.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 31.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 34.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 43.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 44.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 44.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 44.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 46.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 48.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 55.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 56.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 56.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 56.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 59.0
#  dBed step 1 -9.0
#  dBed step 2 -2.0
#  dBed step 3 61.0
#  dBed step 1 -9.0
#  dBed step 2 -3.0
#  dBed step 3 68.0
#  dBed step 1 -9.0
#  dBed step 2 -3.0
#  dBed step 3 70.0
#  dBed step 1 -9.0
#  dBed step 2 -3.0
#  dBed step 3 70.0
#  dBed step 1 -9.0
#  dBed step 2 -3.0
#  dBed step 3 69.0
#  dBed step 1 -9.0
#  dBed step 2 -3.0
#  dBed step 3 71.0
#  dBed step 1 -9.0
#  dBed step 2 -3.0
#  dBed step 3 73.0
#  dBed step 1 -10.0
#  dBed step 2 -3.0
#  dBed step 3 78.0
#  dBed step 1 -10.0
#  dBed step 2 -3.0
#  dBed step 3 79.0
#  dBed step 1 -10.0
#  dBed step 2 -3.0
#  dBed step 3 79.0
#  dBed step 1 -10.0
#  dBed step 2 -3.0
#  dBed step 3 78.0
#  dBed step 1 -10.0
#  dBed step 2 -3.0
#  dBed step 3 80.0
#  dBed step 1 -10.0
#  dBed step 2 -3.0
#  dBed step 3 81.0
#  dBed step 1 -11.0
#  dBed step 2 -4.0
#  dBed step 3 86.0
#  dBed step 1 -11.0
#  dBed step 2 -4.0
#  dBed step 3 87.0
#  dBed step 1 -11.0
#  dBed step 2 -4.0
#  dBed step 3 87.0
#  dBed step 1 -11.0
#  dBed step 2 -4.0
#  dBed step 3 86.0
#  dBed step 1 -11.0
#  dBed step 2 -4.0
#  dBed step 3 87.0
#  dBed step 1 -11.0
#  dBed step 2 -4.0
#  dBed step 3 88.0
#  dBed step 1 -13.0
#  dBed step 2 -5.0
#  dBed step 3 92.0
#  dBed step 1 -13.0
#  dBed step 2 -5.0
#  dBed step 3 94.0
#  dBed step 1 -13.0
#  dBed step 2 -5.0
#  dBed step 3 94.0
#  dBed step 1 -13.0
#  dBed step 2 -5.0
#  dBed step 3 92.0
#  dBed step 1 -13.0
#  dBed step 2 -5.0
#  dBed step 3 94.0
#  dBed step 1 -14.0
#  dBed step 2 -6.0
#  dBed step 3 96.0
#  dBed step 1 -16.0
#  dBed step 2 -7.0
#  dBed step 3 104.0
#  dBed step 1 -16.0
#  dBed step 2 -7.0
#  dBed step 3 105.0
#  dBed step 1 -16.0
#  dBed step 2 -7.0
#  dBed step 3 106.0
#  dBed step 1 -16.0
#  dBed step 2 -7.0
#  dBed step 3 104.0
#  dBed step 1 -17.0
#  dBed step 2 -8.0
#  dBed step 3 107.0
#  dBed step 1 -18.0
#  dBed step 2 -8.0
#  dBed step 3 111.0
#  dBed step 1 -20.0
#  dBed step 2 -10.0
#  dBed step 3 128.0
#  dBed step 1 -21.0
#  dBed step 2 -10.0
#  dBed step 3 131.0
#  dBed step 1 -21.0
#  dBed step 2 -10.0
#  dBed step 3 132.0
#  dBed step 1 -21.0
#  dBed step 2 -10.0
#  dBed step 3 130.0
#  dBed step 1 -22.0
#  dBed step 2 -11.0
#  dBed step 3 137.0
#  dBed step 1 -23.0
#  dBed step 2 -12.0
#  dBed step 3 145.0
#  dBed step 1 -28.0
#  dBed step 2 -14.0
#  dBed step 3 184.0
#  dBed step 1 -29.0
#  dBed step 2 -14.0
#  dBed step 3 191.0
#  dBed step 1 -29.0
#  dBed step 2 -15.0
#  dBed step 3 193.0
#  dBed step 1 -29.0
#  dBed step 2 -15.0
#  dBed step 3 190.0
#  dBed step 1 -31.0
#  dBed step 2 -15.0
#  dBed step 3 205.0
#  dBed step 1 -33.0
#  dBed step 2 -16.0
#  dBed step 3 225.0
#  dBed step 1 -43.0
#  dBed step 2 -20.0
#  dBed step 3 312.0
#  dBed step 1 -45.0
#  dBed step 2 -21.0
#  dBed step 3 330.0
#  dBed step 1 -46.0
#  dBed step 2 -21.0
#  dBed step 3 334.0
#  dBed step 1 -45.0
#  dBed step 2 -21.0
#  dBed step 3 327.0
#  dBed step 1 -49.0
#  dBed step 2 -23.0
#  dBed step 3 362.0
#  dBed step 1 -54.0
#  dBed step 2 -24.0
#  dBed step 3 406.0
#  dBed step 1 -77.0
#  dBed step 2 -33.0
#  dBed step 3 615.0
#  dBed step 1 -81.0
#  dBed step 2 -35.0
#  dBed step 3 658.0
#  dBed step 1 -83.0
#  dBed step 2 -35.0
#  dBed step 3 669.0
#  dBed step 1 -80.0
#  dBed step 2 -34.0
#  dBed step 3 649.0
#  dBed step 1 -89.0
#  dBed step 2 -37.0
#  dBed step 3 732.0
#  dBed step 1 -101.0
#  dBed step 2 -41.0
#  dBed step 3 840.0
#  dBed step 1 -159.0
#  dBed step 2 -62.0
#  dBed step 3 1365.0
#  dBed step 1 -171.0
#  dBed step 2 -66.0
#  dBed step 3 1477.0
#  dBed step 1 -174.0
#  dBed step 2 -67.0
#  dBed step 3 1505.0
#  dBed step 1 -168.0
#  dBed step 2 -65.0
#  dBed step 3 1448.0
#  dBed step 1 -191.0
#  dBed step 2 -73.0
#  dBed step 3 1655.0
#  dBed step 1 -221.0
#  dBed step 2 -84.0
#  dBed step 3 1932.0
#  dBed step 1 -376.0
#  dBed step 2 -138.0
#  dBed step 3 3334.0
#  dBed step 1 -411.0
#  dBed step 2 -150.0
#  dBed step 3 3644.0
#  dBed step 1 -419.0
#  dBed step 2 -153.0
#  dBed step 3 3721.0
#  dBed step 1 -400.0
#  dBed step 2 -147.0
#  dBed step 3 3553.0
#  dBed step 1 -462.0
#  dBed step 2 -168.0
#  dBed step 3 4108.0
#  dBed step 1 -546.0
#  dBed step 2 -197.0
#  dBed step 3 4863.0
#  dBed step 1 -985.0
#  dBed step 2 -350.0
#  dBed step 3 8817.0
#  dBed step 1 -1085.0
#  dBed step 2 -384.0
#  dBed step 3 9716.0
#  dBed step 1 -1110.0
#  dBed step 2 -393.0
#  dBed step 3 9939.0
#  dBed step 1 -1054.0
#  dBed step 2 -373.0
#  dBed step 3 9434.0
#  dBed step 1 -1227.0
#  dBed step 2 -433.0
#  dBed step 3 10989.0
#  dBed step 1 -1465.0
#  dBed step 2 -516.0
#  dBed step 3 13134.0
#  dBed step 1 -2746.0
#  dBed step 2 -957.0
#  dBed step 3 24619.0
#  dBed step 1 -3042.0
#  dBed step 2 -1059.0
#  dBed step 3 27270.0
#  dBed step 1 -3116.0
#  dBed step 2 -1084.0
#  dBed step 3 27928.0
#  dBed step 1 -2946.0
#  dBed step 2 -1026.0
#  dBed step 3 26409.0
#  dBed step 1 -3474.0
#  dBed step 2 -1208.0
#  dBed step 3 31135.0
#  dBed step 1 -2873.0
#  dBed step 2 -119.0
#  dBed step 3 39129.0
#  dBed step 1 -6169.0
#  dBed step 2 -694.0
#  dBed step 3 59177.0
#  dBed step 1 -7550.0
#  dBed step 2 -1431.0
#  dBed step 3 39887.0
#  dBed step 1 -7550.0
#  dBed step 2 -1259.0
#  dBed step 3 34535.0
#  dBed step 1 -1489.0
#  dBed step 2 3852.0
#  dBed step 3 54741.0
#  dBed step 1 -3286.0
#  dBed step 2 -1143.0
#  dBed step 3 29456.0
#  dBed step 1 -3415.0
#  dBed step 2 -987.0
#  dBed step 3 33640.0
#  dBed step 1 -2370.0
#  dBed step 2 1376.0
#  dBed step 3 54636.0
#  dBed step 1 -2482.0
#  dBed step 2 1533.0
#  dBed step 3 58607.0
#  dBed step 1 -2517.0
#  dBed step 2 1565.0
#  dBed step 3 59570.0
#  dBed step 1 -2062.0
#  dBed step 2 1890.0
#  dBed step 3 57663.0
#  dBed step 1 -1840.0
#  dBed step 2 2558.0
#  dBed step 3 64231.0
#  dBed step 1 -1678.0
#  dBed step 2 3269.0
#  dBed step 3 71795.0
#  dBed step 1 -1054.0
#  dBed step 2 6069.0
#  dBed step 3 27492.0
#  dBed step 1 -863.0
#  dBed step 2 6647.0
#  dBed step 3 12689.0
#  dBed step 1 -818.0
#  dBed step 2 6811.0
#  dBed step 3 9530.0
#  dBed step 1 -1154.0
#  dBed step 2 6716.0
#  dBed step 3 39125.0
#  dBed step 1 -1072.0
#  dBed step 2 7689.0
#  dBed step 3 33902.0
#  dBed step 1 -1010.0
#  dBed step 2 8931.0
#  dBed step 3 29970.0
#  dBed step 1 -783.0
#  dBed step 2 14412.0
#  dBed step 3 15502.0
#  dBed step 1 -721.0
#  dBed step 2 11540.0
#  dBed step 3 11540.0
#  dBed step 1 -707.0
#  dBed step 2 10618.0
#  dBed step 3 10618.0
#  dBed step 1 -808.0
#  dBed step 2 14270.0
#  dBed step 3 17077.0
#  dBed step 1 -1088.0
#  dBed step 2 7496.0
#  dBed step 3 34936.0
#  dBed step 1 -1035.0
#  dBed step 2 8454.0
#  dBed step 3 31552.0
#  dBed step 1 -853.0
#  dBed step 2 12469.0
#  dBed step 3 19964.0
#  dBed step 1 -814.0
#  dBed step 2 13256.0
#  dBed step 3 17471.0
#  dBed step 1 -805.0
#  dBed step 2 13456.0
#  dBed step 3 16889.0
#  dBed step 1 -856.0
#  dBed step 2 13078.0
#  dBed step 3 20122.0
#  dBed step 1 -812.0
#  dBed step 2 14730.0
#  dBed step 3 17327.0
#  dBed step 1 -780.0
#  dBed step 2 15254.0
#  dBed step 3 15254.0
#  dBed step 1 -658.0
#  dBed step 2 7482.0
#  dBed step 3 7482.0
#  dBed step 1 -623.0
#  dBed step 2 5246.0
#  dBed step 3 5246.0
#  dBed step 1 -614.0
#  dBed step 2 4726.0
#  dBed step 3 4726.0
#  dBed step 1 -674.0
#  dBed step 2 8492.0
#  dBed step 3 8492.0
#  dBed step 1 -660.0
#  dBed step 2 7655.0
#  dBed step 3 7655.0
#  dBed step 1 -650.0
#  dBed step 2 6963.0
#  dBed step 3 6963.0
#  dBed step 1 -613.0
#  dBed step 2 4633.0
#  dBed step 3 4633.0
#  dBed step 1 -606.0
#  dBed step 2 4168.0
#  dBed step 3 4168.0
#  dBed step 1 -604.0
#  dBed step 2 4059.0
#  dBed step 3 4059.0
#  dBed step 1 -613.0
#  dBed step 2 4602.0
#  dBed step 3 4602.0
#  dBed step 1 -602.0
#  dBed step 2 3932.0
#  dBed step 3 3932.0
#  dBed step 1 -594.0
#  dBed step 2 3444.0
#  dBed step 3 3444.0
#  dBed step 1 -565.0
#  dBed step 2 1568.0
#  dBed step 3 1568.0
#  dBed step 1 -556.0
#  dBed step 2 995.0
#  dBed step 3 995.0
#  dBed step 1 -554.0
#  dBed step 2 862.0
#  dBed step 3 862.0
#  dBed step 1 -570.0
#  dBed step 2 1862.0
#  dBed step 3 1862.0
#  dBed step 1 -565.0
#  dBed step 2 1593.0
#  dBed step 3 1593.0
#  dBed step 1 -562.0
#  dBed step 2 1397.0
#  dBed step 3 1397.0
#  dBed step 1 -550.0
#  dBed step 2 645.0
#  dBed step 3 645.0
#  dBed step 1 -547.0
#  dBed step 2 418.0
#  dBed step 3 418.0
#  dBed step 1 -546.0
#  dBed step 2 365.0
#  dBed step 3 365.0
#  dBed step 1 -552.0
#  dBed step 2 759.0
#  dBed step 3 759.0
#  dBed step 1 -550.0
#  dBed step 2 640.0
#  dBed step 3 640.0
#  dBed step 1 -549.0
#  dBed step 2 555.0
#  dBed step 3 555.0
#  dBed step 1 -544.0
#  dBed step 2 215.0
#  dBed step 3 215.0
#  dBed step 1 -542.0
#  dBed step 2 100.0
#  dBed step 3 100.0
#  dBed step 1 -542.0
#  dBed step 2 73.0
#  dBed step 3 73.0
#  dBed step 1 -545.0
#  dBed step 2 285.0
#  dBed step 3 285.0
#  dBed step 1 -544.0
#  dBed step 2 240.0
#  dBed step 3 240.0
#  dBed step 1 -544.0
#  dBed step 2 208.0
#  dBed step 3 208.0
#  dBed step 1 -542.0
#  dBed step 2 78.0
#  dBed step 3 78.0
#  dBed step 1 -541.0
#  dBed step 2 34.0
#  dBed step 3 34.0
#  dBed step 1 -541.0
#  dBed step 2 23.0
#  dBed step 3 23.0
#  dBed step 1 -542.0
#  dBed step 2 106.0
#  dBed step 3 106.0
#  dBed step 1 -542.0
#  dBed step 2 88.0
#  dBed step 3 88.0
#  dBed step 1 -542.0
#  dBed step 2 76.0
#  dBed step 3 76.0
#  dBed step 1 -541.0
#  dBed step 2 25.0
#  dBed step 3 25.0
#  dBed step 1 -540.0
#  dBed step 2 7.0
#  dBed step 3 7.0
#  dBed step 1 -540.0
#  dBed step 2 3.0
#  dBed step 3 3.0
#  dBed step 1 -541.0
#  dBed step 2 38.0
#  dBed step 3 38.0
#  dBed step 1 -541.0
#  dBed step 2 31.0
#  dBed step 3 31.0
#  dBed step 1 -541.0
#  dBed step 2 27.0
#  dBed step 3 27.0
#  dBed step 1 -540.0
#  dBed step 2 8.0
#  dBed step 3 8.0
#  dBed step 1 -540.0
#  dBed step 2 2.0
#  dBed step 3 2.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -541.0
#  dBed step 2 13.0
#  dBed step 3 13.0
#  dBed step 1 -541.0
#  dBed step 2 11.0
#  dBed step 3 11.0
#  dBed step 1 -541.0
#  dBed step 2 9.0
#  dBed step 3 9.0
#  dBed step 1 -540.0
#  dBed step 2 3.0
#  dBed step 3 3.0
#  dBed step 1 -540.0
#  dBed step 2 1.0
#  dBed step 3 1.0
#  dBed step 1 -540.0
#  dBed step 2 1.0
#  dBed step 3 1.0
#  dBed step 1 -540.0
#  dBed step 2 5.0
#  dBed step 3 5.0
#  dBed step 1 -540.0
#  dBed step 2 4.0
#  dBed step 3 4.0
#  dBed step 1 -540.0
#  dBed step 2 3.0
#  dBed step 3 3.0
#  dBed step 1 -540.0
#  dBed step 2 1.0
#  dBed step 3 1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 1.0
#  dBed step 3 1.0
#  dBed step 1 -540.0
#  dBed step 2 1.0
#  dBed step 3 1.0
#  dBed step 1 -540.0
#  dBed step 2 1.0
#  dBed step 3 1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3
# ODE:  19%|███████▊                                 |  ETA: 0:00:01
# 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -540.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -535.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -527.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -525.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -526.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -510.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -496.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -446.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -440.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -438.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -439.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -425.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -412.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -368.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -362.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -361.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -361.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -351.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -341.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -309.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -304.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -303.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -304.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -295.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -287.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -260.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -257.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -256.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -256.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -249.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -242.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -219.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -216.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -215.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -215.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -211.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -206.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -189.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -187.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -187.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -187.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -182.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -178.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -162.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -160.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -160.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -160.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -156.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -153.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -141.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -139.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -139.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -139.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -135.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -132.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -122.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -120.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -120.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -120.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -118.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -115.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -108.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -107.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -106.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -106.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -104.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -102.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -94.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -93.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -93.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -93.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -91.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -89.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -82.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -82.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -81.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -81.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -80.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -78.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -73.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -72.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -72.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -72.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -70.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -69.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -64.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -63.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -63.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -63.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -62.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -61.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -57.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -56.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -56.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -56.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -55.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -54.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -50.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -50.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -50.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -50.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -49.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -48.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -45.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -44.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -44.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -44.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -43.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -42.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -40.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -40.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -40.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -39.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -39.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -38.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -36.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -36.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -36.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -36.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -35.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -34.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -32.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -32.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -32.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -32.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -32.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -31.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -29.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -29.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -29.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -29.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -29.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -28.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -27.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -26.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -26.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -26.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -26.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -26.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -24.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -24.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -24.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -24.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -24.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -23.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -22.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -22.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -22.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -22.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -22.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -22.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -21.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -21.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -21.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -21.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -21.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -20.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -20.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -20.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -20.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -20.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -19.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -19.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -18.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -18.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -18.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -18.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -18.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -18.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -18.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -18.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -18.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -18.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -17.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -17.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -17.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -17.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -17.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -17.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -17.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -17.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -16.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -16.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -16.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -16.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -16.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -16.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -15.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -14.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
# ODE:  80%|████████████████████████████████▋        |  ETA: 0:00:00
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -13.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
# ...
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -12.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -11.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -11.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -11.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -11.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -11.0
#  dBed step 2 -2.0
#  dBed step 3 0.0
#  dBed step 1 -9.0
#  dBed step 2 -3.0
#  dBed step 3 -2.0
#  dBed step 1 -10.0
#  dBed step 2 -11.0
#  dBed step 3 -4.0
#  dBed step 1 -16.0
#  dBed step 2 -19.0
#  dBed step 3 -6.0
#  dBed step 1 -17.0
#  dBed step 2 -21.0
#  dBed step 3 -6.0
#  dBed step 1 -4.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -11.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -11.0
#  dBed step 2 -2.0
#  dBed step 3 0.0
#  dBed step 1 -5.0
#  dBed step 2 0.0
#  dBed step 3 -1.0
#  dBed step 1 0.0
#  dBed step 2 -1.0
#  dBed step 3 -3.0
#  dBed step 1 0.0
#  dBed step 2 -1.0
#  dBed step 3 -4.0
#  dBed step 1 -12.0
#  dBed step 2 -9.0
#  dBed step 3 -8.0
#  dBed step 1 -11.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -11.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -11.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -11.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -10.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -10.0
#  dBed step 2 -3.0
#  dBed step 3 -2.0
#  dBed step 1 -11.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -11.0
#  dBed step 2 0.0
#  dBed step 3 0.0
#  dBed step 1 -11.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -11.0
#  dBed step 2 -3.0
#  dBed step 3 -1.0
#  dBed step 1 -11.0
#  dBed step 2 -3.0
#  dBed step 3 -1.0
#  dBed step 1 -10.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -10.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -10.0
#  dBed step 2 -3.0
#  dBed step 3 -1.0
#  dBed step 1 -9.0
#  dBed step 2 -4.0
#  dBed step 3 -2.0
#  dBed step 1 -9.0
#  dBed step 2 -4.0
#  dBed step 3 -3.0
#  dBed step 1 -9.0
#  dBed step 2 -4.0
#  dBed step 3 -3.0
#  dBed step 1 -9.0
#  dBed step 2 -3.0
#  dBed step 3 -2.0
#  dBed step 1 -9.0
#  dBed step 2 -4.0
#  dBed step 3 -2.0
#  dBed step 1 -8.0
#  dBed step 2 -4.0
#  dBed step 3 -2.0
#  dBed step 1 -7.0
#  dBed step 2 -4.0
#  dBed step 3 -3.0
#  dBed step 1 -7.0
#  dBed step 2 -5.0
#  dBed step 3 -4.0
#  dBed step 1 -7.0
#  dBed step 2 -5.0
#  dBed step 3 -4.0
#  dBed step 1 -6.0
#  dBed step 2 -3.0
#  dBed step 3 -2.0
#  dBed step 1 -6.0
#  dBed step 2 -3.0
#  dBed step 3 -2.0
#  dBed step 1 -6.0
#  dBed step 2 -3.0
#  dBed step 3 -2.0
#  dBed step 1 -5.0
#  dBed step 2 -3.0
#  dBed step 3 -2.0
#  dBed step 1 -5.0
#  dBed step 2 -3.0
#  dBed step 3 -2.0
#  dBed step 1 -5.0
#  dBed step 2 -3.0
#  dBed step 3 -2.0
#  dBed step 1 -5.0
#  dBed step 2 -3.0
#  dBed step 3 -2.0
#  dBed step 1 -4.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -4.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -3.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -3.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -3.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -3.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -3.0
#  dBed step 2 -2.0
#  dBed step 3 -1.0
#  dBed step 1 -3.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -2.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
# ODE: 100%|█████████████████████████████████████████| Time: 0:00:00
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 -1.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
#  dBed step 1 -1.0
#  dBed step 2 -1.0
#  dBed step 3 0.0
# retcode: Success
# Interpolation: specialized 4th order "free" interpolation
# t: 177-element Array{Float64,1}:
#    0.0
#    0.010256793903171088
#    0.08505036060820434
#    0.1670351185427555
#    0.33074081439146663
#    0.4985957839081823
#    0.7589234239406004
#    1.0450365024130441
#    1.416449797627635
#    1.851007251225926
#    2.3826364987750033
#    3.007049485547713
#    3.7458823758989994
#    ⋮
#  246.03437288775476
#  247.70445680522428
#  249.05537704410776
#  250.7643226740026
#  252.60163887669825
#  254.95577002436102
#  257.8301711937976
#  261.5751237754185
#  265.9466500789549
#  270.27050879698743
#  274.1217199378869
#  275.0
# u: 177-element Array{Array{Float64,2},1}:
#  [4.994996e6; 5.733447e6; … ; 1128.0; 1.0]
#  [4.994995567658474e6; 5.733446504615949e6; … ; 1128.0994620171282; 1.0856798665813456]
#  [4.99499245002277e6; 5.733442930778434e6; … ; 1129.2387686400893; 1.7075854987430663]
#  [4.994989101790113e6; 5.733439089596336e6; … ; 1131.2568699568826; 2.381621571158568]
#  [4.994982622956618e6; 5.733431648733209e6; … ; 1137.3324753717943; 3.6982973527796927]
#  [4.994976250027369e6; 5.733424320013386e6; … ; 1145.8446056571463; 5.010159206413988]
#  [4.994966864408865e6; 5.733413512034147e6; … ; 1162.3724559981938; 7.0030693523261975]
#  [4.99495718232162e6; 5.733402347395281e6; … ; 1183.689003403966; 9.222141770795748]
#  [4.994945486093461e6; 5.7333888440802125e6; … ; 1214.3993482809171; 12.330183028423194]
#  [4.9949328813784765e6; 5.733374277338421e6; … ; 1253.301535202121; 16.553949693248587]
#  [4.994918787783695e6; 5.73335797767382e6; … ; 1305.562162584629; 22.92716389038919]
#  [4.9949037523292005e6; 5.733340579360077e6; … ; 1378.1429223431098; 32.57443320464982]
#  [4.994887631967394e6; 5.733321918378943e6; … ; 1494.3647797548058; 48.02134933652968]
#  ⋮
#  [4.994443857712283e6; 5.732774217410451e6; … ; 165383.9993248242; 62.13260743057227]
#  [4.994443485584256e6; 5.732773845201942e6; … ; 165383.99986827417; 55.691537449059005]
#  [4.994443179476599e6; 5.7327735390316e6; … ; 165383.99996566487; 51.00903547053801]
#  [4.994442785612141e6; 5.7327731450907625e6; … ; 165383.9999935083; 45.69540565341421]
#  [4.99444235377077e6; 5.732772713170704e6; … ; 165383.9999988817; 40.661058762788315]
#  [4.994441787522808e6; 5.732772146826756e6; … ; 165383.9999998172; 35.10466666957363]
#  [4.994441076034584e6; 5.732771435228125e6; … ; 165383.9999999423; 29.472621590380303]
#  [4.994440115136962e6; 5.732770474196771e6; … ; 165383.99999991214; 23.672633171383147]
#  [4.994438943693979e6; 5.732769302610499e6; … ; 165383.99999963373; 18.600515453095895]
#  [4.994437731054376e6; 5.7327680898411e6; … ; 165383.99999857892; 14.92352429127438]
#  [4.994436604993708e6; 5.732766963673636e6; … ; 165383.99999740833; 12.480237823907785]
#  [4.994436342074716e6; 5.732766700731354e6; … ; 165383.99999892293; 12.010324504172333]

# %%
# The solutions are returned as an Array of Arrays: 
#  - it is a vector of size the number of timesteps
#  - each element of the vector is a vector of all the variables
nSteps = length(sol.t)
nVars  = length(sol.u[1])

# Empty dataframe to contain all the numbers
# (When running a loop at top-level, the global keywrod is necessary to modify global variables.)
solDF = zeros((nSteps, nVars))
for i = 1:nSteps
    global solDF
    solDF[i, :] = sol.u[i]
end

solDF = hcat(DataFrame(t = sol.t), DataFrame(solDF))

# Let's clean the names
compartments =  ["S", "E", "I", "J", "H", "C", "R", "D", "K", "L"]
solnames = vcat([:t], [Symbol(c * repr(n)) for c in compartments for n in 0:(nAgeGroup-1)], [:Beds], [:ICU])
rename!(solDF, solnames)
# Out:
# 177×93 DataFrame. Omitted printing of 87 columns
# │ Row │ t         │ S0        │ S1        │ S2        │ S3        │ S4        │
# │     │ Float64   │ Float64   │ Float64   │ Float64   │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┼───────────┼───────────┼───────────┼───────────┤
# │ 1   │ 0.0       │ 4.995e6   │ 5.73345e6 │ 6.10344e6 │ 6.99843e6 │ 9.022e6   │
# │ 2   │ 0.0102568 │ 4.995e6   │ 5.73345e6 │ 6.10344e6 │ 6.99843e6 │ 9.022e6   │
# │ 3   │ 0.0850504 │ 4.99499e6 │ 5.73344e6 │ 6.10343e6 │ 6.99842e6 │ 9.02198e6 │
# │ 4   │ 0.167035  │ 4.99499e6 │ 5.73344e6 │ 6.10342e6 │ 6.9984e6  │ 9.02195e6 │
# │ 5   │ 0.330741  │ 4.99498e6 │ 5.73343e6 │ 6.1034e6  │ 6.99838e6 │ 9.0219e6  │
# │ 6   │ 0.498596  │ 4.99498e6 │ 5.73342e6 │ 6.10339e6 │ 6.99835e6 │ 9.02185e6 │
# │ 7   │ 0.758923  │ 4.99497e6 │ 5.73341e6 │ 6.10336e6 │ 6.9983e6  │ 9.02177e6 │
# │ 8   │ 1.04504   │ 4.99496e6 │ 5.7334e6  │ 6.10334e6 │ 6.99826e6 │ 9.02168e6 │
# │ 9   │ 1.41645   │ 4.99495e6 │ 5.73339e6 │ 6.10331e6 │ 6.99819e6 │ 9.02156e6 │
# │ 10  │ 1.85101   │ 4.99493e6 │ 5.73337e6 │ 6.10327e6 │ 6.99812e6 │ 9.02141e6 │
# ⋮
# │ 167 │ 247.704   │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │
# │ 168 │ 249.055   │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │
# │ 169 │ 250.764   │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │
# │ 170 │ 252.602   │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │
# │ 171 │ 254.956   │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │
# │ 172 │ 257.83    │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │
# │ 173 │ 261.575   │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │
# │ 174 │ 265.947   │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │
# │ 175 │ 270.271   │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │
# │ 176 │ 274.122   │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │
# │ 177 │ 275.0     │ 4.99444e6 │ 5.73277e6 │ 0.1       │ 0.1       │ 0.1       │

# %%
# Create sums for each compartment
for c in compartments
    col =  [Symbol(c * repr(n)) for n in 0:(nAgeGroup-1)]
    s = DataFrame(C = sum.(eachrow(solDF[:, col])))
    rename!(s, [Symbol(c)])
        
    solDF = hcat(solDF, s)
end

# The D column gives the final number of dead.
last(solDF[:, Symbol.(compartments)], 10)
# Out:
# 10×10 DataFrame. Omitted printing of 4 columns
# │ Row │ S         │ E       │ I       │ J       │ H        │ C       │
# │     │ Float64   │ Float64 │ Float64 │ Float64 │ Float64  │ Float64 │
# ├─────┼───────────┼─────────┼─────────┼─────────┼──────────┼─────────┤
# │ 1   │ 1.07272e7 │ 2.8635  │ 1.95999 │ 0.9     │ 0.905637 │ 59.009  │
# │ 2   │ 1.07272e7 │ 2.90454 │ 1.98077 │ 0.9     │ 0.901066 │ 53.6954 │
# │ 3   │ 1.07272e7 │ 2.94985 │ 2.00652 │ 0.9     │ 0.900184 │ 48.6611 │
# │ 4   │ 1.07272e7 │ 3.00922 │ 2.04098 │ 0.9     │ 0.90003  │ 43.1047 │
# │ 5   │ 1.07272e7 │ 3.08352 │ 2.08428 │ 0.9     │ 0.900009 │ 37.4726 │
# │ 6   │ 1.07272e7 │ 3.18311 │ 2.14248 │ 0.9     │ 0.900014 │ 31.6726 │
# │ 7   │ 1.07272e7 │ 3.30301 │ 2.2128  │ 0.9     │ 0.90006  │ 26.6005 │
# │ 8   │ 1.07272e7 │ 3.42493 │ 2.28466 │ 0.9     │ 0.900233 │ 22.9235 │
# │ 9   │ 1.07272e7 │ 3.53577 │ 2.35026 │ 0.9     │ 0.900425 │ 20.4802 │
# │ 10  │ 1.07272e7 │ 3.56126 │ 2.36518 │ 0.9     │ 0.900177 │ 20.0103 │

# %% [markdown]
# The last row shows the final sizes of the various compartments.
#
# Next is the evolution of the over time.

# %%
@df solDF plot(:t, :S, label = "S", legend = :topright, title = "Compartments size")
@df solDF plot!(:t, :E, label = "E")
@df solDF plot!(:t, :I, label = "I")
@df solDF plot!(:t, :J, label = "J")
@df solDF plot!(:t, :H, label = "H")
@df solDF plot!(:t, :K, label = "K")
@df solDF plot!(:t, :L, label = "L")
@df solDF plot!(:t, :C, label = "C")
@df solDF plot!(:t, :D, label = "D")
@df solDF plot!(:t, :R, label = "R")

plot!(yaxis = (:log10))

# %%
@df solDF plot(:t, [:D0 ,:D1, :D2, :D3, :D4, :D5, :D6, :D7, :D8], title = "Deaths by age group", yscale = :log10, legend = :bottomright)

# %%
@df solDF plot( :t, :Beds, label = "BED", legend = :topright, title = "Bed usage")
@df solDF plot!(:t, :ICU, label = "ICU")

# %% [markdown]
# # Bilibliography
#
# The Novel Coronavirus Pneumonia Emergency Response Epidemiology Team. The Epidemiological Characteristics of an Outbreak of 2019 Novel Coronavirus Diseases (COVID-19) — China, 2020[J]. China CDC Weekly, 2020, 2(8): 113-122. [LINK](http://weekly.chinacdc.cn/en/article/id/e53946e2-c6c4-41e9-9a9b-fea8db1a8f51)
